# %% [markdown]
# # Training, Testing and Validating

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt

pd.options.display.max_rows = 10
pd.options.display.float_format = "{:.1f}".format

# %%
# download the data
train_df = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv")
test_df = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_test.csv")

# %%
scale_factor = 1000.0

# Scale the training set's label.
train_df["median_house_value"] /= scale_factor 

# Scale the test set's label
test_df["median_house_value"] /= scale_factor

# %% [markdown]
# ## DEFINE FUNCTIONS

# %%
def build_model(my_learning_rate):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Add one linear layer to the model to yield a simple linear regressor.
  model.add(tf.keras.layers.Dense(units=1, input_shape=(1,)))

  # Compile the model topography into code that TensorFlow can efficiently
  # execute. Configure training to minimize the model's mean squared error. 
  model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.RootMeanSquaredError()])

  return model               


def train_model(model, df, feature, label, my_epochs, 
                my_batch_size=None, my_validation_split=0.1):
  """Feed a dataset into the model in order to train it."""

  history = model.fit(x=df[feature],
                      y=df[label],
                      batch_size=my_batch_size,
                      epochs=my_epochs,
                      validation_split=my_validation_split)

  # Gather the model's trained weight and bias.
  trained_weight = model.get_weights()[0]
  trained_bias = model.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
  epochs = history.epoch
  
  # Isolate the root mean squared error for each epoch.
  hist = pd.DataFrame(history.history)
  rmse = hist["root_mean_squared_error"]

  return epochs, rmse, history.history   

print("Defined the build_model and train_model functions.")

def plot_the_loss_curve(epochs, mae_training, mae_validation):
  """Plot a curve of loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")

  plt.plot(epochs[1:], mae_training[1:], label="Training Loss")
  plt.plot(epochs[1:], mae_validation[1:], label="Validation Loss")
  plt.legend()
  
  # We're not going to plot the first epoch, since the loss on the first epoch
  # is often substantially greater than the loss for other epochs.
  merged_mae_lists = mae_training[1:] + mae_validation[1:]
  highest_loss = max(merged_mae_lists)
  lowest_loss = min(merged_mae_lists)
  delta = highest_loss - lowest_loss
  print(delta)

  top_of_y_axis = highest_loss + (delta * 0.05)
  bottom_of_y_axis = lowest_loss - (delta * 0.05)
   
  plt.ylim([bottom_of_y_axis, top_of_y_axis])
  plt.show()  

print("Defined the plot_the_loss_curve function.")
# Out:
# Defined the build_model and train_model functions.
# Defined the plot_the_loss_curve function.

# %% [markdown]
# ## Introduce a Test/Validation Split

# %%
# The following variables are the hyperparameters.
learning_rate = 0.1
epochs = 30
batch_size = 120

# Split the original training set into a reduced training set and a
# validation set. 
validation_split=0.2

# Identify the feature and the label.
my_feature="median_income"  # the median income on a specific city block.
my_label="median_house_value" # the median value of a house on a specific city block.
# That is, you're going to create a model that predicts house value based 
# solely on the neighborhood's median income.  

# Discard any pre-existing version of the model.
my_model = None

# Invoke the functions to build and train the model.
my_model = build_model(learning_rate)
epochs, rmse, history = train_model(my_model, train_df, my_feature, 
                                    my_label, epochs, batch_size, 
                                    validation_split)

plot_the_loss_curve(epochs, history["root_mean_squared_error"], 
                    history["val_root_mean_squared_error"])
# Out:
# Epoch 1/30
# 114/114 [==============================] - 0s 2ms/step - loss: 40944.5742 - root_mean_squared_error: 202.3477 - val_loss: 48881.1445 - val_root_mean_squared_error: 221.0908
# Epoch 2/30
# 114/114 [==============================] - 0s 2ms/step - loss: 23065.1582 - root_mean_squared_error: 151.8722 - val_loss: 27912.2910 - val_root_mean_squared_error: 167.0697
# Epoch 3/30
# 114/114 [==============================] - 0s 2ms/step - loss: 11921.6299 - root_mean_squared_error: 109.1862 - val_loss: 14874.2012 - val_root_mean_squared_error: 121.9598
# Epoch 4/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7104.1948 - root_mean_squared_error: 84.2864 - val_loss: 9481.7178 - val_root_mean_squared_error: 97.3741
# Epoch 5/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6512.4062 - root_mean_squared_error: 80.6995 - val_loss: 9107.5537 - val_root_mean_squared_error: 95.4335
# Epoch 6/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6514.2310 - root_mean_squared_error: 80.7108 - val_loss: 9233.8516 - val_root_mean_squared_error: 96.0929
# Epoch 7/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6513.7812 - root_mean_squared_error: 80.7080 - val_loss: 9391.4668 - val_root_mean_squared_error: 96.9096
# Epoch 8/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6513.1118 - root_mean_squared_error: 80.7038 - val_loss: 9196.3799 - val_root_mean_squared_error: 95.8978
# Epoch 9/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6513.0200 - root_mean_squared_error: 80.7033 - val_loss: 9342.6260 - val_root_mean_squared_error: 96.6573
# Epoch 10/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6514.3076 - root_mean_squared_error: 80.7113 - val_loss: 9259.7998 - val_root_mean_squared_error: 96.2279
# Epoch 11/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6513.4019 - root_mean_squared_error: 80.7057 - val_loss: 9353.2031 - val_root_mean_squared_error: 96.7120
# Epoch 12/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6513.7695 - root_mean_squared_error: 80.7079 - val_loss: 9194.1494 - val_root_mean_squared_error: 95.8861
# Epoch 13/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6514.2383 - root_mean_squared_error: 80.7108 - val_loss: 9101.4678 - val_root_mean_squared_error: 95.4016
# Epoch 14/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6515.0264 - root_mean_squared_error: 80.7157 - val_loss: 9226.0029 - val_root_mean_squared_error: 96.0521
# Epoch 15/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6513.8789 - root_mean_squared_error: 80.7086 - val_loss: 9154.3662 - val_root_mean_squared_error: 95.6785
# Epoch 16/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6514.1836 - root_mean_squared_error: 80.7105 - val_loss: 9200.4375 - val_root_mean_squared_error: 95.9189
# Epoch 17/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6514.3945 - root_mean_squared_error: 80.7118 - val_loss: 9244.5479 - val_root_mean_squared_error: 96.1486
# Epoch 18/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6513.4346 - root_mean_squared_error: 80.7058 - val_loss: 9294.3730 - val_root_mean_squared_error: 96.4073
# Epoch 19/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6512.6455 - root_mean_squared_error: 80.7010 - val_loss: 9429.5986 - val_root_mean_squared_error: 97.1061
# Epoch 20/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6514.8066 - root_mean_squared_error: 80.7144 - val_loss: 9176.9922 - val_root_mean_squared_error: 95.7966
# Epoch 21/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6514.1455 - root_mean_squared_error: 80.7103 - val_loss: 9423.7627 - val_root_mean_squared_error: 97.0761
# Epoch 22/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6512.9072 - root_mean_squared_error: 80.7026 - val_loss: 9451.3574 - val_root_mean_squared_error: 97.2181
# Epoch 23/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6512.9253 - root_mean_squared_error: 80.7027 - val_loss: 9464.6680 - val_root_mean_squared_error: 97.2865
# Epoch 24/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6515.1841 - root_mean_squared_error: 80.7167 - val_loss: 9376.6533 - val_root_mean_squared_error: 96.8331
# Epoch 25/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6514.5947 - root_mean_squared_error: 80.7130 - val_loss: 9238.0273 - val_root_mean_squared_error: 96.1147
# Epoch 26/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6514.4443 - root_mean_squared_error: 80.7121 - val_loss: 9283.8457 - val_root_mean_squared_error: 96.3527
# Epoch 27/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6513.7622 - root_mean_squared_error: 80.7079 - val_loss: 9167.6074 - val_root_mean_squared_error: 95.7476
# Epoch 28/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6514.0767 - root_mean_squared_error: 80.7098 - val_loss: 9123.9316 - val_root_mean_squared_error: 95.5193
# Epoch 29/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6514.8472 - root_mean_squared_error: 80.7146 - val_loss: 9184.7158 - val_root_mean_squared_error: 95.8369
# Epoch 30/30
# 114/114 [==============================] - 0s 2ms/step - loss: 6513.1138 - root_mean_squared_error: 80.7039 - val_loss: 9135.4297 - val_root_mean_squared_error: 95.5794
# 86.3702392578125

# %% [markdown]
# ### Shuffle the traing set as it is ordered by Longitude

# %%
# The following variables are the hyperparameters.
learning_rate = 0.1
epochs = 30
batch_size = 120

# Split the original training set into a reduced training set and a
# validation set. 
validation_split=0.2

# Identify the feature and the label.
my_feature="median_income"  # the median income on a specific city block.
my_label="median_house_value" # the median value of a house on a specific city block.
# That is, you're going to create a model that predicts house value based 
# solely on the neighborhood's median income.  

# Discard any pre-existing version of the model.
my_model = None

# Shuffle the examples.
shuffled_train_df = train_df.reindex(np.random.permutation(train_df.index)) 

# Invoke the functions to build and train the model. Train on the shuffled
# training set.
my_model = build_model(learning_rate)
epochs, rmse, history = train_model(my_model, shuffled_train_df, my_feature, 
                                    my_label, epochs, batch_size, 
                                    validation_split)

plot_the_loss_curve(epochs, history["root_mean_squared_error"], 
                    history["val_root_mean_squared_error"])
# Out:
# Epoch 1/30
# 114/114 [==============================] - 0s 2ms/step - loss: 43810.7539 - root_mean_squared_error: 209.3102 - val_loss: 33803.4141 - val_root_mean_squared_error: 183.8570
# Epoch 2/30
# 114/114 [==============================] - 0s 2ms/step - loss: 24920.5645 - root_mean_squared_error: 157.8625 - val_loss: 18372.3750 - val_root_mean_squared_error: 135.5447
# Epoch 3/30
# 114/114 [==============================] - 0s 2ms/step - loss: 13043.9434 - root_mean_squared_error: 114.2101 - val_loss: 9592.2783 - val_root_mean_squared_error: 97.9402
# Epoch 4/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7727.5356 - root_mean_squared_error: 87.9064 - val_loss: 6994.2949 - val_root_mean_squared_error: 83.6319
# Epoch 5/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7029.9541 - root_mean_squared_error: 83.8448 - val_loss: 6949.7808 - val_root_mean_squared_error: 83.3653
# Epoch 6/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7028.6455 - root_mean_squared_error: 83.8370 - val_loss: 6950.9048 - val_root_mean_squared_error: 83.3721
# Epoch 7/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7030.4229 - root_mean_squared_error: 83.8476 - val_loss: 6961.9121 - val_root_mean_squared_error: 83.4381
# Epoch 8/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7028.6660 - root_mean_squared_error: 83.8371 - val_loss: 6953.7075 - val_root_mean_squared_error: 83.3889
# Epoch 9/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7029.3511 - root_mean_squared_error: 83.8412 - val_loss: 6949.7578 - val_root_mean_squared_error: 83.3652
# Epoch 10/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7029.6484 - root_mean_squared_error: 83.8430 - val_loss: 6957.4971 - val_root_mean_squared_error: 83.4116
# Epoch 11/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7029.3540 - root_mean_squared_error: 83.8412 - val_loss: 6956.9502 - val_root_mean_squared_error: 83.4083
# Epoch 12/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7029.5596 - root_mean_squared_error: 83.8425 - val_loss: 6966.5684 - val_root_mean_squared_error: 83.4660
# Epoch 13/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7028.8457 - root_mean_squared_error: 83.8382 - val_loss: 6950.2417 - val_root_mean_squared_error: 83.3681
# Epoch 14/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7028.3765 - root_mean_squared_error: 83.8354 - val_loss: 6956.2798 - val_root_mean_squared_error: 83.4043
# Epoch 15/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7029.5449 - root_mean_squared_error: 83.8424 - val_loss: 6961.9951 - val_root_mean_squared_error: 83.4386
# Epoch 16/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7027.5435 - root_mean_squared_error: 83.8304 - val_loss: 6946.6382 - val_root_mean_squared_error: 83.3465
# Epoch 17/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7030.8418 - root_mean_squared_error: 83.8501 - val_loss: 6967.8667 - val_root_mean_squared_error: 83.4737
# Epoch 18/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7029.3115 - root_mean_squared_error: 83.8410 - val_loss: 6957.1177 - val_root_mean_squared_error: 83.4093
# Epoch 19/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7028.3013 - root_mean_squared_error: 83.8350 - val_loss: 6956.4868 - val_root_mean_squared_error: 83.4056
# Epoch 20/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7029.3735 - root_mean_squared_error: 83.8414 - val_loss: 6948.8457 - val_root_mean_squared_error: 83.3597
# Epoch 21/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7030.2188 - root_mean_squared_error: 83.8464 - val_loss: 6976.8813 - val_root_mean_squared_error: 83.5277
# Epoch 22/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7029.2451 - root_mean_squared_error: 83.8406 - val_loss: 6980.3823 - val_root_mean_squared_error: 83.5487
# Epoch 23/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7029.4302 - root_mean_squared_error: 83.8417 - val_loss: 6961.1875 - val_root_mean_squared_error: 83.4337
# Epoch 24/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7029.0698 - root_mean_squared_error: 83.8395 - val_loss: 6963.3447 - val_root_mean_squared_error: 83.4467
# Epoch 25/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7028.8687 - root_mean_squared_error: 83.8383 - val_loss: 6966.1426 - val_root_mean_squared_error: 83.4634
# Epoch 26/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7028.8813 - root_mean_squared_error: 83.8384 - val_loss: 6949.5054 - val_root_mean_squared_error: 83.3637
# Epoch 27/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7029.0391 - root_mean_squared_error: 83.8394 - val_loss: 6947.7368 - val_root_mean_squared_error: 83.3531
# Epoch 28/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7029.4253 - root_mean_squared_error: 83.8417 - val_loss: 6977.2144 - val_root_mean_squared_error: 83.5297
# Epoch 29/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7029.9473 - root_mean_squared_error: 83.8448 - val_loss: 6958.9473 - val_root_mean_squared_error: 83.4203
# Epoch 30/30
# 114/114 [==============================] - 0s 2ms/step - loss: 7029.2358 - root_mean_squared_error: 83.8405 - val_loss: 6971.9331 - val_root_mean_squared_error: 83.4981
# 74.5159912109375

# %% [markdown]
# ### Evaluate the models performance on the final test set against the one above

# %%
x_test = test_df[my_feature]
y_test = test_df[my_label]

results = my_model.evaluate(x_test, y_test, batch_size=batch_size)
# Out:
# 25/25 [==============================] - 0s 1ms/step - loss: 7016.7681 - root_mean_squared_error: 83.7662
